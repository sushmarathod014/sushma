# %%
import pandas as pd

# %%
df=pd.read_csv('dataset/Salary_Data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(data=df, x='YearsExperience',y='Salary')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['YearsExperience']],df[['Salary']])

# %%
x_train
# Out:
#     YearsExperience
# 3               2.0
# 23              8.2
# 24              8.7
# 18              5.9
# 13              4.1
# 16              5.1
# 14              4.5
# 15              4.9
# 8               3.2
# 17              5.3
# 11              4.0
# 21              7.1
# 9               3.7
# 0               1.1
# 5               2.9
# 7               3.2
# 25              9.0
# 1               1.3
# 26              9.5
# 12              4.0
# 22              7.9
# 2               1.5

# %%
x_test
# Out:
#     YearsExperience
# 4               2.2
# 6               3.0
# 27              9.6
# 10              3.9
# 20              6.8
# 28             10.3
# 19              6.0
# 29             10.5

# %%
y_train
# Out:
#       Salary
# 3    43525.0
# 23  113812.0
# 24  109431.0
# 18   81363.0
# 13   57081.0
# 16   66029.0
# 14   61111.0
# 15   67938.0
# 8    64445.0
# 17   83088.0
# 11   55794.0
# 21   98273.0
# 9    57189.0
# 0    39343.0
# 5    56642.0
# 7    54445.0
# 25  105582.0
# 1    46205.0
# 26  116969.0
# 12   56957.0
# 22  101302.0
# 2    37731.0

# %%
y_test
# Out:
#       Salary
# 4    39891.0
# 6    60150.0
# 27  112635.0
# 10   63218.0
# 20   91738.0
# 28  122391.0
# 19   93940.0
# 29  121872.0

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([[ 46002.68683712],
#        [ 53664.64103928],
#        [116875.76320709],
#        [ 62284.33951671],
#        [ 90058.92349953],
#        [123579.97313398],
#        [ 82396.96929737],
#        [125495.46168452]])

# %%
x_pred=lr.predict(x_train)
x_pred
# Out:
# array([[ 44087.19828658],
#        [103467.34335331],
#        [108256.06472966],
#        [ 81439.2250221 ],
#        [ 64199.82806724],
#        [ 73777.27081994],
#        [ 68030.80516832],
#        [ 71861.7822694 ],
#        [ 55580.12958982],
#        [ 75692.75937048],
#        [ 63242.08379198],
#        [ 92932.15632534],
#        [ 60368.85096617],
#        [ 35467.49980915],
#        [ 52706.89676401],
#        [ 55580.12958982],
#        [111129.29755547],
#        [ 37382.98835969],
#        [115918.01893182],
#        [ 63242.08379198],
#        [100594.1105275 ],
#        [ 39298.47691023]])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 5577.548506174114

# %%
print("Mean Squared Error:",mse)
print("Root Mean Squared Error:",rmse)
print("R2 Score:",r2)
# Out:
# Mean Squared Error: 31109047.33872509
# Root Mean Squared Error: 5577.548506174114
# R2 Score: 0.9627994441068174

# %%
plt.scatter(x_train, y_train, color="green") 
plt.plot(x_train, x_pred, color="red") 
plt.title("Salary vs Experience (Training Dataset)") 
plt.xlabel("Years of Experience") 
plt.ylabel("Salary(In Rupees)") 
plt.show()
