# %%
# training and testing model

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataset/Salary_Data.csv')

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x=df[['YearsExperience']]
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y=df[['Salary']]
y
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['YearsExperience']],df[['Salary']],test_size=0.2)

# %%
x_train
# Out:
#     YearsExperience
# 28             10.3
# 11              4.0
# 5               2.9
# 13              4.1
# 3               2.0
# 25              9.0
# 9               3.7
# 2               1.5
# 16              5.1
# 6               3.0
# 17              5.3
# 21              7.1
# 20              6.8
# 15              4.9
# 7               3.2
# 1               1.3
# 19              6.0
# 14              4.5
# 18              5.9
# 23              8.2
# 12              4.0
# 8               3.2
# 22              7.9
# 4               2.2

# %%
y_train
# Out:
#       Salary
# 28  122391.0
# 11   55794.0
# 5    56642.0
# 13   57081.0
# 3    43525.0
# 25  105582.0
# 9    57189.0
# 2    37731.0
# 16   66029.0
# 6    60150.0
# 17   83088.0
# 21   98273.0
# 20   91738.0
# 15   67938.0
# 7    54445.0
# 1    46205.0
# 19   93940.0
# 14   61111.0
# 18   81363.0
# 23  113812.0
# 12   56957.0
# 8    64445.0
# 22  101302.0
# 4    39891.0

# %%
y_test
# Out:
#       Salary
# 10   63218.0
# 0    39343.0
# 26  116969.0
# 29  121872.0
# 24  109431.0
# 27  112635.0

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred1=lr.predict(x_test)
x_pred1=lr.predict(x_train)

# %%
y_pred1
# Out:
# array([[ 62410.95697121],
#        [ 35187.61068076],
#        [116857.64955209],
#        [126580.27322725],
#        [109079.55061197],
#        [117829.91191961]])

# %%
x_pred1
# Out:
# array([[124635.74849222],
#        [ 63383.21933872],
#        [ 52688.33329605],
#        [ 64355.48170624],
#        [ 43937.9719884 ],
#        [111996.33771451],
#        [ 60466.43223617],
#        [ 39076.66015082],
#        [ 74078.1053814 ],
#        [ 53660.59566356],
#        [ 76022.63011643],
#        [ 93523.35273171],
#        [ 90606.56562917],
#        [ 72133.58064636],
#        [ 55605.12039859],
#        [ 37132.13541579],
#        [ 82828.46668904],
#        [ 68244.5311763 ],
#        [ 81856.20432152],
#        [104218.23877439],
#        [ 63383.21933872],
#        [ 55605.12039859],
#        [101301.45167184],
#        [ 45882.49672344]])

# %%
#prediction for test data
y_pred1=lr.predict(x_test)
y_pred1
# Out:
# array([[ 62410.95697121],
#        [ 35187.61068076],
#        [116857.64955209],
#        [126580.27322725],
#        [109079.55061197],
#        [117829.91191961]])

# %%
plt.scatter(x_train,y_train,color='green')
plt.plot(x_train,x_pred,color='red')
plt.plot(x_train,x_pred,color='purple')
plt.title('salary vs experiece(training dataset)')
plt.xlabel('years of experience')
plt.ylabel('salary in rupees')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 plt.scatter(x_train,y_train,color='green')
# ----> 2 plt.plot(x_train,x_pred,color='red')
#       3 plt.plot(x_train,x_pred,color='purple')
#       4 plt.title('salary vs experiece(training dataset)')
#
# NameError: name 'x_pred' is not defined

# %%
#prediction for test data
y_pred1=lr.predict(x_test)
y_pred1
# Out:
# array([[ 62410.95697121],
#        [ 35187.61068076],
#        [116857.64955209],
#        [126580.27322725],
#        [109079.55061197],
#        [117829.91191961]])

# %%
#performace metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
import numpy as np
mse=mean_squared_error(y_test,y_pred1)
mae=mean_absolute_error(y_test,y_pred1)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 11201573.512390053
# 2554.7362218058565
# 3346.8751862580793

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred1)
print(score)
# Out:
# 0.9884612534146818

# %% [markdown]
# # RandomForestRegression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=100 , random_state=0)
rfr.fit(x_train , y_train)
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_6260\972859175.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfr.fit(x_train , y_train)
# RandomForestRegressor(random_state=0)

# %%
#prediction for test data
y_pred2=rfr.predict(x_test)
y_pred2
# Out:
# array([ 56494.01521429,  43712.71      , 110118.1       , 116505.52      ,
#        107185.53      , 110118.1       ])

# %%
#performace metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mse_RFR=mean_squared_error(y_test,y_pred2)
mae_RFR=mean_absolute_error(y_test,y_pred2)
rmse_RFR=np.sqrt(mse_RFR)
print(mse_RFR)
print(mae_RFR)
print(rmse_RFR)
# Out:
# 25236199.402319502
# 4678.907464285711
# 5023.564412080282

# %%
from sklearn.metrics import r2_score
r2_RFR=r2_score(y_test,y_pred2)
print(r2_RFR)
# Out:
# 0.9740041781310605

# %% [markdown]
# # SupportVectorRegression

# %%
from sklearn.svm import SVR
svr = SVR(kernel='rbf')
svr.fit(x_train,y_train)
# Out:
# C:\Users\bldea\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
y_pred3 = svr.predict(x_test)
y_pred3
# Out:
# array([62777.75108591, 62776.82803001, 62786.53007993, 62785.02835258,
#        62787.72222   , 62786.37487988])

# %%
#performace metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mse_SVR=mean_squared_error(y_test,y_pred3)
mae_SVR=mean_absolute_error(y_test,y_pred3)
rmse_SVR=np.sqrt(mse_SVR)
print(mse_SVR)
print(mae_SVR)
print(rmse_SVR)
# Out:
# 1939471528.1294463
# 38939.236901950426
# 44039.431514603435

# %%
r2_SVR=r2_score(y_test,y_pred3)
print(r2_SVR)
# Out:
# -0.9978506098069138

# %% [markdown]
# # LassoRegression

# %%
from sklearn.linear_model import Lasso
la = Lasso(alpha=3.0)
la.fit(x_train , y_train)
# Out:
# Lasso(alpha=3.0)

# %%
y_pred4 = la.predict(x_test)
y_pred4
# Out:
# array([ 62411.46034099,  35189.61744829, 116855.14612638, 126577.23287378,
#        109077.47672847, 117827.35480112])

# %%
mse_LA=mean_squared_error(y_test,y_pred4)
mae_LA=mean_absolute_error(y_test,y_pred4)
rmse_LA=np.sqrt(mse_LA)
print(mse_LA)
print(mae_LA)
print(rmse_LA)
# Out:
# 11189799.837945418
# 2554.147838461801
# 3345.115818315626

# %%
r2_LA=r2_score(y_test,y_pred4)
print(r2_LA)
# Out:
# 0.9884733814827291

# %%
df1 = pd.DataFrame({'Regression_Name':['LinearRegression','RandomForestRegression','SupportVectorRegression','LassoRegression'] , 'r2_score':[score,r2_RFR,r2_SVR,r2_LA] , 'mse':[mse,mse_RFR,mse_SVR,mse_LA] ,'mae':[mae,mae_RFR,mae_SVR,mae_LA],'rmse':[rmse,rmse_RFR,rmse_SVR,rmse_LA]})
df1
# Out:
#            Regression_Name  r2_score           mse           mae          rmse
# 0         LinearRegression  0.988461  1.120157e+07   2554.736222   3346.875186
# 1   RandomForestRegression  0.974004  2.523620e+07   4678.907464   5023.564412
# 2  SupportVectorRegression -0.997851  1.939472e+09  38939.236902  44039.431515
# 3          LassoRegression  0.988473  1.118980e+07   2554.147838   3345.115818

# %% [markdown]
# # 2 dataset

# %%
import pandas as pd
df=pd.read_csv('dataset/50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida  110352.25
# 23   67532.53       105751.03        304768.73     Florida  108733.99
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25   64664.71       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# 34   46426.07       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42   23640.93        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00    New York   35673.41
# 49       0.00       116983.80         45173.06  California   14681.40

# %%
x=df[['R&D Spend','Administration','Marketing Spend','Profit']]
x
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# 15  114523.61       122616.84        261776.23  129917.04
# 16   78013.11       121597.55        264346.06  126992.93
# 17   94657.16       145077.58        282574.31  125370.37
# 18   91749.16       114175.79        294919.57  124266.90
# 19   86419.70       153514.11             0.00  122776.86
# 20   76253.86       113867.30        298664.47  118474.03
# 21   78389.47       153773.43        299737.29  111313.02
# 22   73994.56       122782.75        303319.26  110352.25
# 23   67532.53       105751.03        304768.73  108733.99
# 24   77044.01        99281.34        140574.81  108552.04
# 25   64664.71       139553.16        137962.62  107404.34
# 26   75328.87       144135.98        134050.07  105733.54
# 27   72107.60       127864.55        353183.81  105008.31
# 28   66051.52       182645.56        118148.20  103282.38
# 29   65605.48       153032.06        107138.38  101004.64
# 30   61994.48       115641.28         91131.24   99937.59
# 31   61136.38       152701.92         88218.23   97483.56
# 32   63408.86       129219.61         46085.25   97427.84
# 33   55493.95       103057.49        214634.81   96778.92
# 34   46426.07       157693.92        210797.67   96712.80
# 35   46014.02        85047.44        205517.64   96479.51
# 36   28663.76       127056.21        201126.82   90708.19
# 37   44069.95        51283.14        197029.42   89949.14
# 38   20229.59        65947.93        185265.10   81229.06
# 39   38558.51        82982.09        174999.30   81005.76
# 40   28754.33       118546.05        172795.67   78239.91
# 41   27892.92        84710.77        164470.71   77798.83
# 42   23640.93        96189.63        148001.11   71498.49
# 43   15505.73       127382.30         35534.17   69758.98
# 44   22177.74       154806.14         28334.72   65200.33
# 45    1000.23       124153.04          1903.93   64926.08
# 46    1315.46       115816.21        297114.46   49490.75
# 47       0.00       135426.92             0.00   42559.73
# 48     542.05        51743.15             0.00   35673.41
# 49       0.00       116983.80         45173.06   14681.40

# %%
y=df[['State']]
y
# Out:
#          State
# 0     New York
# 1   California
# 2      Florida
# 3     New York
# 4      Florida
# 5     New York
# 6   California
# 7      Florida
# 8     New York
# 9   California
# 10     Florida
# 11  California
# 12     Florida
# 13  California
# 14     Florida
# 15    New York
# 16  California
# 17    New York
# 18     Florida
# 19    New York
# 20  California
# 21    New York
# 22     Florida
# 23     Florida
# 24    New York
# 25  California
# 26     Florida
# 27    New York
# 28     Florida
# 29    New York
# 30     Florida
# 31    New York
# 32  California
# 33     Florida
# 34  California
# 35    New York
# 36     Florida
# 37  California
# 38    New York
# 39  California
# 40  California
# 41     Florida
# 42  California
# 43    New York
# 44  California
# 45    New York
# 46     Florida
# 47  California
# 48    New York
# 49  California

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb= LabelEncoder()
import numpy as np

# %%
df['State']=lb.fit_transform(df['State'])
y
# Out:
#          State
# 0     New York
# 1   California
# 2      Florida
# 3     New York
# 4      Florida
# 5     New York
# 6   California
# 7      Florida
# 8     New York
# 9   California
# 10     Florida
# 11  California
# 12     Florida
# 13  California
# 14     Florida
# 15    New York
# 16  California
# 17    New York
# 18     Florida
# 19    New York
# 20  California
# 21    New York
# 22     Florida
# 23     Florida
# 24    New York
# 25  California
# 26     Florida
# 27    New York
# 28     Florida
# 29    New York
# 30     Florida
# 31    New York
# 32  California
# 33     Florida
# 34  California
# 35    New York
# 36     Florida
# 37  California
# 38    New York
# 39  California
# 40  California
# 41     Florida
# 42  California
# 43    New York
# 44  California
# 45    New York
# 46     Florida
# 47  California
# 48    New York
# 49  California

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x,df['State'], test_size= 0.2, random_state=0)

# %%
x_train
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 33   55493.95       103057.49        214634.81   96778.92
# 35   46014.02        85047.44        205517.64   96479.51
# 26   75328.87       144135.98        134050.07  105733.54
# 34   46426.07       157693.92        210797.67   96712.80
# 18   91749.16       114175.79        294919.57  124266.90
# 7   130298.13       145530.06        323876.68  155752.60
# 14  119943.24       156547.42        256512.92  132602.65
# 45    1000.23       124153.04          1903.93   64926.08
# 48     542.05        51743.15             0.00   35673.41
# 29   65605.48       153032.06        107138.38  101004.64
# 15  114523.61       122616.84        261776.23  129917.04
# 30   61994.48       115641.28         91131.24   99937.59
# 32   63408.86       129219.61         46085.25   97427.84
# 16   78013.11       121597.55        264346.06  126992.93
# 42   23640.93        96189.63        148001.11   71498.49
# 20   76253.86       113867.30        298664.47  118474.03
# 43   15505.73       127382.30         35534.17   69758.98
# 8   120542.52       148718.95        311613.29  152211.77
# 13   91992.39       135495.07        252664.93  134307.35
# 25   64664.71       139553.16        137962.62  107404.34
# 5   131876.90        99814.71        362861.36  156991.12
# 17   94657.16       145077.58        282574.31  125370.37
# 40   28754.33       118546.05        172795.67   78239.91
# 49       0.00       116983.80         45173.06   14681.40
# 1   162597.70       151377.59        443898.53  191792.06
# 12   93863.75       127320.38        249839.44  141585.52
# 37   44069.95        51283.14        197029.42   89949.14
# 24   77044.01        99281.34        140574.81  108552.04
# 6   134615.46       147198.87        127716.82  156122.51
# 23   67532.53       105751.03        304768.73  108733.99
# 36   28663.76       127056.21        201126.82   90708.19
# 21   78389.47       153773.43        299737.29  111313.02
# 19   86419.70       153514.11             0.00  122776.86
# 9   123334.88       108679.17        304981.62  149759.96
# 39   38558.51        82982.09        174999.30   81005.76
# 46    1315.46       115816.21        297114.46   49490.75
# 3   144372.41       118671.85        383199.62  182901.99
# 0   165349.20       136897.80        471784.10  192261.83
# 47       0.00       135426.92             0.00   42559.73
# 44   22177.74       154806.14         28334.72   65200.33

# %%
x_test
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 28   66051.52       182645.56        118148.20  103282.38
# 11  100671.96        91790.61        249744.55  144259.40
# 10  101913.08       110594.11        229160.95  146121.95
# 41   27892.92        84710.77        164470.71   77798.83
# 2   153441.51       101145.55        407934.54  191050.39
# 27   72107.60       127864.55        353183.81  105008.31
# 38   20229.59        65947.93        185265.10   81229.06
# 31   61136.38       152701.92         88218.23   97483.56
# 22   73994.56       122782.75        303319.26  110352.25
# 4   142107.34        91391.77        366168.42  166187.94

# %%
y_train
# Out:
# 33    1
# 35    2
# 26    1
# 34    0
# 18    1
# 7     1
# 14    1
# 45    2
# 48    2
# 29    2
# 15    2
# 30    1
# 32    0
# 16    0
# 42    0
# 20    0
# 43    2
# 8     2
# 13    0
# 25    0
# 5     2
# 17    2
# 40    0
# 49    0
# 1     0
# 12    1
# 37    0
# 24    2
# 6     0
# 23    1
# 36    1
# 21    2
# 19    2
# 9     0
# 39    0
# 46    1
# 3     2
# 0     2
# 47    0
# 44    0
# Name: State, dtype: int32

# %%
y_test
# Out:
# 28    1
# 11    0
# 10    1
# 41    1
# 2     1
# 27    2
# 38    2
# 31    2
# 22    1
# 4     1
# Name: State, dtype: int32

# %% [markdown]
# # LinearRegression

# %%
#Fitting the MLR model to the training set:  
from sklearn.linear_model import LinearRegression  
lr= LinearRegression()  
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred5=lr.predict(x_test)

# %%
y_pred5
# Out:
# array([0.81622751, 1.18519102, 1.15777474, 0.86633137, 1.32645913,
#        0.81012273, 0.88866527, 0.89152569, 0.88320127, 1.28264602])

# %%
print('train score:',lr.score(x_train,y_train))
print('test score:',lr.score(x_test,y_test))
# Out:
# train score: 0.040653974992037156
# test score: -0.5446957326391808

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
mse=mean_squared_error(y_test,y_pred5)
mse
# Out:
# 0.5560904637501052

# %%
mae=mean_absolute_error(y_test,y_pred5)
mae
# Out:
# 0.5795997077830057

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 0.7457147334940522

# %%
r2=r2_score(y_test,y_pred5)
r2
# Out:
# -0.5446957326391808

# %%
print('mean squared error',mse)
print('root mean squared error',rmse)
print('R2_score',r2)
print(mae)
# Out:
# mean squared error 0.5560904637501052
# root mean squared error 0.7457147334940522
# R2_score -0.5446957326391808
# 0.5795997077830057

# %% [markdown]
# # RandomForestRegression

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=100 , random_state=0)
rfr.fit(x_train , y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
#prediction for test data
y_pred6=rfr.predict(x_test)
y_pred6
# Out:
# array([1.01, 1.29, 0.75, 0.42, 1.71, 1.14, 0.38, 0.93, 0.94, 1.69])

# %%
#performace metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mse_RFR=mean_squared_error(y_test,y_pred6)
mae_RFR=mean_absolute_error(y_test,y_pred6)
rmse_RFR=np.sqrt(mse_RFR)
print(mse_RFR)
print(mae_RFR)
print(rmse_RFR)
# Out:
# 0.7555799999999999
# 0.7139999999999999
# 0.8692410482714216

# %%
r2_RFR=r2_score(y_test,y_pred6)
print(r2_RFR)
# Out:
# -1.0988333333333329

# %% [markdown]
# # SupportVectorRegression

# %%
from sklearn.svm import SVR
svr = SVR(kernel='rbf')
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred3 = svr.predict(x_test)
y_pred3
# Out:
# array([0.85119594, 0.83927202, 0.79688057, 0.26353338, 1.96627509,
#        1.49404728, 0.23708213, 0.92788786, 1.13537533, 1.79225576])

# %%
#performace metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mse_SVR=mean_squared_error(y_test,y_pred3)
mae_SVR=mean_absolute_error(y_test,y_pred3)
rmse_SVR=np.sqrt(mse_SVR)
print(mse_SVR)
print(mae_SVR)
print(rmse_SVR)
# Out:
# 0.7403136003771053
# 0.7162551055386743
# 0.8604147839136106

# %%
r2_SVR=r2_score(y_test,y_pred3)
print(r2_SVR)
# Out:
# -1.056426667714181

# %% [markdown]
# # LassoRegression

# %%
from sklearn.linear_model import Lasso
la = Lasso(alpha=3.0)
la.fit(x_train , y_train)
# Out:
# Lasso(alpha=3.0)

# %%
y_pred4 = la.predict(x_test)
y_pred4
# Out:
# array([0.81657274, 1.18472965, 1.15740132, 0.86619275, 1.32601794,
#        0.81052899, 0.88837021, 0.89162117, 0.8834076 , 1.28228007])

# %%
mse_LA=mean_squared_error(y_test,y_pred4)
mae_LA=mean_absolute_error(y_test,y_pred4)
rmse_LA=np.sqrt(mse_LA)
print(mse_LA)
print(mae_LA)
print(rmse_LA)
# Out:
# 0.5558538673880339
# 0.5793735513998854
# 0.7455560793045912

# %%
r2_LA=r2_score(y_test,y_pred4)
print(r2_LA)
# Out:
# -0.5440385205223162

# %%
df1 = pd.DataFrame({'Regression_Name':['LinearRegression','RandomForestRegression','SupportVectorRegression','LassoRegression'] , 'r2_score':[score,r2_RFR,r2_SVR,r2_LA] , 'mse':[mse,mse_RFR,mse_SVR,mse_LA] ,'mae':[mae,mae_RFR,mae_SVR,mae_LA],'rmse':[rmse,rmse_RFR,rmse_SVR,rmse_LA]})
df1
# Out:
#            Regression_Name  r2_score       mse       mae      rmse
# 0         LinearRegression  0.988461  0.556090  0.579600  0.745715
# 1   RandomForestRegression -1.098833  0.755580  0.714000  0.869241
# 2  SupportVectorRegression -1.056427  0.740314  0.716255  0.860415
# 3          LassoRegression -0.544039  0.555854  0.579374  0.745556
