# %% [markdown]
# # training and testing model

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataset/Salary_Data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x=df['YearsExperience']
x
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     4.1
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     9.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# Name: YearsExperience, dtype: float64

# %%
y=df['Salary']
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['YearsExperience']],df[['Salary']],test_size=0.2)

# %%
x_trainfrom sklearn.model_selection import train_test_split
# Out:
#     YearsExperience
# 15              4.9
# 2               1.5
# 11              4.0
# 16              5.1
# 6               3.0
# 4               2.2
# 5               2.9
# 8               3.2
# 3               2.0
# 27              9.6
# 7               3.2
# 13              4.1
# 1               1.3
# 10              3.9
# 28             10.3
# 17              5.3
# 23              8.2
# 14              4.5
# 25              9.0
# 9               3.7
# 21              7.1
# 19              6.0
# 20              6.8
# 29             10.5

# %%
y_train
# Out:
#       Salary
# 15   67938.0
# 2    37731.0
# 11   55794.0
# 16   66029.0
# 6    60150.0
# 4    39891.0
# 5    56642.0
# 8    64445.0
# 3    43525.0
# 27  112635.0
# 7    54445.0
# 13   57081.0
# 1    46205.0
# 10   63218.0
# 28  122391.0
# 17   83088.0
# 23  113812.0
# 14   61111.0
# 25  105582.0
# 9    57189.0
# 21   98273.0
# 19   93940.0
# 20   91738.0
# 29  121872.0

# %%
y_test
# Out:
#       Salary
# 24  109431.0
# 22  101302.0
# 12   56957.0
# 18   81363.0
# 0    39343.0
# 26  116969.0

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
x_pred=lr.predict(x_train)

# %%
y_pred
# Out:
# array([[107838.67500583],
#        [100315.87084269],
#        [ 63642.20054736],
#        [ 81508.86043483],
#        [ 36372.03545597],
#        [115361.47916897]])

# %%
x_pred
# Out:
# array([[ 72105.3552309 ],
#        [ 40133.43753754],
#        [ 63642.20054736],
#        [ 73986.05627168],
#        [ 54238.69534343],
#        [ 46715.89118029],
#        [ 53298.34482304],
#        [ 56119.39638422],
#        [ 44835.1901395 ],
#        [116301.82968937],
#        [ 56119.39638422],
#        [ 64582.55106775],
#        [ 38252.73649675],
#        [ 62701.85002697],
#        [122884.28333212],
#        [ 75866.75731247],
#        [103136.92240386],
#        [ 68343.95314933],
#        [110659.72656701],
#        [ 60821.14898618],
#        [ 92793.06667954],
#        [ 82449.21095522],
#        [ 89972.01511836],
#        [124764.9843729 ]])

# %%
x_pred=lr.predict(x_train)

# %%
plt.scatter(x_train,y_train,color='green')
plt.plot(x_train,x_pred,color='red')
plt.plot(x_train,x_pred,color='purple')
plt.title('salary vs experience(training dataset)')
plt.xlabel('years of experience')
plt.ylabel('salary in rupees')
plt.show()

# %% [markdown]
# # Model Evaluation and Testing

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
sns.regplot(x=y_test,y=y_pred,ci=None,color='blue')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 9938647.46182396

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 3152.562047259968

# %%
#coefficient of determination or R_Squared(R2)
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.9874861337025389

# %%
print('mean squared error:',mse)
print('root mean squared error:',rmse)
print('R2_score:',r2)
# Out:
# mean squared error: 9938647.46182396
# root mean squared error: 3152.562047259968
# R2_score: 0.9874861337025389

# %% [markdown]
# # 2 dataset

# %%
import pandas as pd
df=pd.read_csv('dataset/50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
x=df[['R&D Spend','Administration','Marketing Spend','Profit']]
x
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# ...

# %%
y=df['State']
y
# Out:
# 0       New York
# 1     California
# 2        Florida
# 3       New York
# 4        Florida
# 5       New York
# 6     California
# 7        Florida
# 8       New York
# 9     California
# 10       Florida
# 11    California
# 12       Florida
# 13    California
# 14       Florida
# 15      New York
# 16    California
# 17      New York
# 18       Florida
# 19      New York
# 20    California
# 21      New York
# 22       Florida
# 23       Florida
# 24      New York
# 25    California
# 26       Florida
# 27      New York
# 28       Florida
# 29      New York
# 30       Florida
# 31      New York
# 32    California
# 33       Florida
# 34    California
# 35      New York
# 36       Florida
# 37    California
# 38      New York
# 39    California
# 40    California
# 41       Florida
# 42    California
# 43      New York
# 44    California
# 45      New York
# 46       Florida
# 47    California
# 48      New York
# 49    California
# Name: State, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
df['State']=lb.fit_transform(df['State'])
df
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      2  192261.83
# 1   162597.70       151377.59        443898.53      0  191792.06
# 2   153441.51       101145.55        407934.54      1  191050.39
# 3   144372.41       118671.85        383199.62      2  182901.99
# 4   142107.34        91391.77        366168.42      1  166187.94
# 5   131876.90        99814.71        362861.36      2  156991.12
# 6   134615.46       147198.87        127716.82      0  156122.51
# 7   130298.13       145530.06        323876.68      1  155752.60
# 8   120542.52       148718.95        311613.29      2  152211.77
# 9   123334.88       108679.17        304981.62      0  149759.96
# 10  101913.08       110594.11        229160.95      1  146121.95
# 11  100671.96        91790.61        249744.55      0  144259.40
# 12   93863.75       127320.38        249839.44      1  141585.52
# ...

# %%
y
# Out:
# 0       New York
# 1     California
# 2        Florida
# 3       New York
# 4        Florida
# 5       New York
# 6     California
# 7        Florida
# 8       New York
# 9     California
# 10       Florida
# 11    California
# 12       Florida
# 13    California
# 14       Florida
# 15      New York
# 16    California
# 17      New York
# 18       Florida
# 19      New York
# 20    California
# 21      New York
# 22       Florida
# 23       Florida
# 24      New York
# 25    California
# 26       Florida
# 27      New York
# 28       Florida
# 29      New York
# 30       Florida
# 31      New York
# 32    California
# 33       Florida
# 34    California
# 35      New York
# 36       Florida
# 37    California
# 38      New York
# 39    California
# 40    California
# 41       Florida
# 42    California
# 43      New York
# 44    California
# 45      New York
# 46       Florida
# 47    California
# 48      New York
# 49    California
# Name: State, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,df['State'],test_size=0.2,random_state=0)
x_train
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 33   55493.95       103057.49        214634.81   96778.92
# 35   46014.02        85047.44        205517.64   96479.51
# 26   75328.87       144135.98        134050.07  105733.54
# 34   46426.07       157693.92        210797.67   96712.80
# 18   91749.16       114175.79        294919.57  124266.90
# 7   130298.13       145530.06        323876.68  155752.60
# 14  119943.24       156547.42        256512.92  132602.65
# 45    1000.23       124153.04          1903.93   64926.08
# 48     542.05        51743.15             0.00   35673.41
# 29   65605.48       153032.06        107138.38  101004.64
# 15  114523.61       122616.84        261776.23  129917.04
# 30   61994.48       115641.28         91131.24   99937.59
# 32   63408.86       129219.61         46085.25   97427.84
# 16   78013.11       121597.55        264346.06  126992.93
# 42   23640.93        96189.63        148001.11   71498.49
# ...

# %%
x_test
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 28   66051.52       182645.56        118148.20  103282.38
# 11  100671.96        91790.61        249744.55  144259.40
# 10  101913.08       110594.11        229160.95  146121.95
# 41   27892.92        84710.77        164470.71   77798.83
# 2   153441.51       101145.55        407934.54  191050.39
# 27   72107.60       127864.55        353183.81  105008.31
# 38   20229.59        65947.93        185265.10   81229.06
# 31   61136.38       152701.92         88218.23   97483.56
# 22   73994.56       122782.75        303319.26  110352.25
# 4   142107.34        91391.77        366168.42  166187.94

# %%
y_train
# Out:
# 33    1
# 35    2
# 26    1
# 34    0
# 18    1
# 7     1
# 14    1
# 45    2
# 48    2
# 29    2
# 15    2
# 30    1
# 32    0
# 16    0
# 42    0
# 20    0
# 43    2
# 8     2
# 13    0
# 25    0
# 5     2
# 17    2
# 40    0
# 49    0
# 1     0
# 12    1
# 37    0
# 24    2
# 6     0
# 23    1
# 36    1
# 21    2
# 19    2
# 9     0
# 39    0
# 46    1
# 3     2
# 0     2
# 47    0
# 44    0
# Name: State, dtype: int32

# %%
y_test
# Out:
# 28    1
# 11    0
# 10    1
# 41    1
# 2     1
# 27    2
# 38    2
# 31    2
# 22    1
# 4     1
# Name: State, dtype: int32

# %%
#Finding the MLR model to the training set:
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([0.81622751, 1.18519102, 1.15777474, 0.86633137, 1.32645913,
#        0.81012273, 0.88866527, 0.89152569, 0.88320127, 1.28264602])

# %%
print('train score:',lr.score(x_train,y_train))
print('test score:',lr.score(x_test,y_test))
# Out:
# train score: 0.040653974992037156
# test score: -0.5446957326391808

# %% [markdown]
# # Model Evaluating and testing

# %%
#using 50_startup file

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred);
plt.xlabel('Actual');
plt.ylabel('Predicted')
plt.show()

# %%
import seaborn as sns
sns.regplot(x=y_test,y=y_pred,ci=None,color='red')
plt.show()

# %%
#Evaluating Regression model:
#Evaluating Metric
#Root Mean Squared Error(RSME)
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 0.5560904637501052

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.5795997077830057

# %%
#coefficient of determination or R_Squared(R2)
r2=r2_score(y_test,y_pred)
r2
# Out:
# -0.5446957326391808

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# 0.7457147334940522

# %%
print('mean squared error:',mse)
print('root mean squared error:',rmse)
print('R2_score:',r2)
# Out:
# mean squared error: 0.5560904637501052
# root mean squared error: 0.7457147334940522
# R2_score: -0.5446957326391808
